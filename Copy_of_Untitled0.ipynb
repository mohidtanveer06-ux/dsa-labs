# %% [markdown]
# <a href="https://colab.research.google.com/github/mohidtanveer06-ux/dsa-labs/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("My name is mohid")
print("My age is 20")
print("10")
print(6+3)
# Out:
# My name is mohid
# My age is 20
# 10
# 9

# %%
name="ali"
age=21
height=54

print(name)
print(age)
print(height)
# Out:
# ali
# 21
# 54

# %%
print("My name is ", name)
print("My age is ", 23)
print(type(age))
# Out:
# My name is  ali
# My age is  23
# <class 'int'>

# %%
a=12
b=45
print(a+b,a-b,a*b,a/b)
# Out:
# 57 -33 540 0.26666666666666666

# %%
name= input("Enter your name")
print(name)
height= float(input("Enter height"))
print(height)
# Out:
# Enter your name  mohid
#   mohid
# Enter height  203
# 203.0

# %%
age= int(input("Enter your age"))
if age>=18:
      print("You are adult")
elif age<=18:
      print("You are young")
else:
      print("you are nothing")
# Out:
# Enter your age32
# You are adult

# %%
mark=85
if  mark>=80:
    print("Grade A")
elif  mark>=70:
    print("Grade B")
elif  mark>=60:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade A

# %%
fruit=["Apple","Banana","Orange"]
print(fruit)
print(fruit[0])
print(fruit[1])
print(fruit[2])
fruit.append("grapes")
print(fruit[3])
print(fruit)
fruit.remove("Apple")
print(fruit[0])
print(fruit)
# Out:
# ['Apple', 'Banana', 'Orange']
# Apple
# Banana
# Orange
# grapes
# ['Apple', 'Banana', 'Orange', 'grapes']
# Banana
# ['Banana', 'Orange', 'grapes']
